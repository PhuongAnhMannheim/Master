# %%
import re
from Scripts import loading as dl, profiling as pf, cleaning as cl, preprocessing as prep


db_path = '../Data/moviereviews.db'
db_name = 'moviereviews'
df = dl.load_from_db(db_path, db_name)


print('######## FIRST GENERAL INSIGHT')
print(df.head())
pf.get_review_count(df)
pf.get_descr(df)


print('######## DATA COMPLETENESS')
pf.get_missing_text(df)
pf.get_missing_label(df)
df = pf.get_missing_label_implicit(df)
df = cl.proceed_data_completion(df)


print('######## DUPLICATE DETECTION')
pf.get_duplicates(df)
df = cl.drop_duplicates(df)


print('######### OTHER HEURISTICS')
df = df[~(df.URL.str.contains('telegraph')&(~df.URL.str.contains('film')))]
print("After removing other related mistakes: ", len(df))


print('######## LINGUISTIC AFFILIATION')
df = cl.remove_non_english(df)
# pf.show_lang_dist(df, 'amazon_movie_lang_non_eng_dist', 'non-English Language Distribution (Amazon Movies & TV)', 0)
# pf.show_lang_dist(df, 'amazon_movie_lang_all_dist', 'Language Distribution (Amazon Movies & TV)', 1)


print('######## RATING SCALE ADJUSTMENT')

def chForm(value):
    value = re.sub(r'[a-zA-Z]|@|%| |"|-|\\', '', value)
    # return value
    if value != "":
        value = float(value)
    else:
        print('did not work for: ', value)
    return value
df['REVIEWRATING_new'] = df.apply(lambda row: chForm(row['REVIEWRATING']), axis=1)
df['BESTRATING_new']= df.apply(lambda row: chForm(row['BESTRATING']), axis=1)
df['WORSTRATING_new']= df.apply(lambda row: chForm(row['WORSTRATING']), axis=1)

def adjust_rating(value, source_min, source_max, bins):
    if value >= source_max:
        return bins
    if value < source_min:
        return 1
    source_range = source_max - source_min
    bin_size = source_range/bins
    res = None
    for bound in range(bins):
        lower_bound = (bound * bin_size)+source_min
        upper_bound = ((bound+1) * bin_size)+source_min
        if source_min == 0:
            if value > lower_bound and value <= upper_bound:
                res = bound+1
            elif value == source_min:
                res = 1
        else:
            if value >= lower_bound and value < upper_bound:
                res = bound+1
    return res

df['label'] = df.apply(lambda row: adjust_rating(
    row['REVIEWRATING_new'], row['WORSTRATING_new'], row['BESTRATING_new'], 5), axis=1)

print(df['label'].value_counts(normalize=True))
print(df['label'].value_counts())


print('######## PREPROCESSING')
print('######## Web Data Specific')
df = prep.remove_html(df)
df = prep.remove_hyperlinks(df)
df = prep.remove_between_square_brackets(df)
df = prep.remove_between_angle_brackets(df)
df = prep.unescape(df)
df = prep.remove_whitespaces(df)
df = prep.remove_lang_ind(df)

print('######## Text Harmonization')
df = prep.replace_contractions(df)
df = prep.remove_accented_chars(df)
df = prep.to_token(df)
total_token_count = pf.get_total_token_count(df)
print(total_token_count)
df = prep.transform_abbr(df)
df = prep.remove_numbers(df)
df = prep.remove_punct_and_nonascii(df)
df = prep.to_lower(df)
df = prep.remove_stopwords(df)
df = prep.get_pos(df)

print('######## Text Canonicalization')
df = prep.stem(df)

pf.get_prep_summary(df, total_token_count)

df = prep.detokenize(df)

print('######## DATA COMPLETION AFTER PREPROCESSING')
total_prep = len(df)
df_empty = df[df.text_prep=='']
print("Empty preprocessed text:", len(df_empty))
print("Duplicate preprocessed text: {:.2%}".format(len(df_empty) / total_prep))
df = df[df.text_prep!='']
print("After removing empty preprocessed texts: ", len(df))

print('######## DEDUPLICATION AFTER PREPROCESSING')
df_dup = df[df.duplicated(subset=['text_prep'], keep='last')]
print("Duplicate preprocessed text:", len(df_dup))
print("Duplicate preprocessed text: {:.2%}".format(len(df_dup) / total_prep))
df = df.drop_duplicates(subset=['text_prep'], keep='last')
print("After removing duplicate preprocessed texts: ", len(df))


print('######### LAST CHECK')
print(df.head())
print(df.describe(include='all'))
 #%%

print('######## DATA SOURCES')
df = pf.get_source_info(df)
print('#### All sources across ratings')
print('#### rating class 1.0')
print(df[df.label==1.0]['netloc'].value_counts())
print('#### rating class 2.0')
print(df[df.label==2.0]['netloc'].value_counts())
print('#### rating class 3.0')
print(df[df.label==3.0]['netloc'].value_counts())
print('#### rating class 4.0')
print(df[df.label==4.0]['netloc'].value_counts())
print('#### rating class 5.0')
print(df[df.label==5.0]['netloc'].value_counts())

 #%%

print('######## STORING')
df = df[['NODE','URL', 'text', 'label', 'text_prep', 'token_count', 'upper', 'pos']]
df.columns=['NODE', 'URL','text', 'label', 'text_prep', 'token_count', 'upper', 'pos']
df.to_pickle('../Data/schema_movie.pkl')
print('to pickle done')
# Out:
# ######## FIRST GENERAL INSIGHT
#                                      NODE  \
# 0  _:nodea456ab92b2669279485e1ddc64944bf0
# 1   _:nodee7b066aef1465ef6796152d5b23eefd
# 2   _:node3b52118bf545246233aa662aad8a194
# 3     _:nodef82d8af1d090997015dbe94ab45ad
# 4   _:nodeecc0f025103514ba011df1542adef7b
#
#                                                  URL  \
# 0  https://in.bookmyshow.com/amritsar/movies/hous...
# 1  https://in.bookmyshow.com/amritsar/movies/hous...
# 2  https://in.bookmyshow.com/amritsar/movies/hous...
# 3  https://in.bookmyshow.com/amritsar/movies/hous...
# 4  https://in.bookmyshow.com/amritsar/movies/hous...
#
#                                                 text REVIEWRATING BESTRATING  \
# 0  "Housefull 4 is about the mistaken identities,...          2.5  "Null"@en
# 1                                               None    "Null"@en  "Null"@en
# 2  "Overall, Housefull 4 ends up as a complete ma...          2.5  "Null"@en
# 3                                               None    "Null"@en  "Null"@en
# 4  "HOUSEFULL 4 is a major disappointment and suf...            2  "Null"@en
#
#   WORSTRATING
# 0      "2"@en
# 1      "2"@en
# 2      "2"@en
# 3      "2"@en
# 4      "2"@en
# ######## Total:
# Amount of reviews:  265629
# ######## DESCRIPTION
#                                         NODE  \
# count                                 265629
# unique                                265627
# top     _:node524c27b56024fa01eb77917a6c642c
# freq                                       2
#
#                                                       URL       text  \
# count                                              265629     187886
# unique                                              36620      91664
# top     https://www.imdb.com/search/title/?title_type=...  "Null"@en
# freq                                                 1522       2415
#
#        REVIEWRATING BESTRATING WORSTRATING
# count        241342     197132      197082
# unique          198         14          19
# top       "Null"@en  "Null"@en           1
# freq          47380      68512       47015
# ######## DATA COMPLETENESS
# Missing/Empty review text: 77894
# Missing review text as percentage: 29.32%
# Missing rating information 68547
# Missing rating information as percentage: 25.81%
# Implicitly missing rating data 34299
# Implicitly missing rating data as percentage: 12.91%
# After removing implictly missing rating information:  96507
# ######## DUPLICATE DETECTION
# Duplicate text: 19511
# Duplicate text: 20.22%
# Duplicate text and label: 19479
# Duplicate text and label from reviews without missing information: 20.18%
# After removing duplicate entries and texts:  76996
# ######### OTHER HEURISTICS
# After removing other related mistakes:  75950
# ######## LINGUISTIC AFFILIATION
# exception: ....
# exception:
# en    75413
# fr       84
# no       60
# pt       43
# it       34
# ro       33
# nl       30
# af       30
# cy       29
# da       26
# ca       24
# tl       21
# es       18
# de       16
# so       15
# sv       15
# et       15
# id       14
# fi        6
# sq        4
# hr        4
# sl        3
# hu        2
# sw        2
# tr        2
# lv        1
# lt        1
# cs        1
# pl        1
# vi        1
# Name: LANGUAGE, dtype: int64
# After removing non-english text: 75413
# ######## RATING SCALE ADJUSTMENT
# 4    0.259438
# 3    0.248445
# 2    0.200005
# 5    0.166921
# 1    0.125191
# Name: label, dtype: float64
# 4    19565
# 3    18736
# 2    15083
# 5    12588
# 1     9441
# Name: label, dtype: int64
# ######## PREPROCESSING
# ######## Web Data Specific
# removed html tags
# removed hyperlinks
# removed content between square brackets
# removed content between angle brackets
# html unescape done
# white space removal done
# language indicator removal done
# ######## Text Harmonization
# contractions expansion done
# removed accented characters
# tokenization done
# 19874726
# abbreviation transformation done
# number removal done
# Token Count:  20077631
# punctuation and non-ascii removal done
# Token Count:  18151849
# ######## LOWERCASING STATISTICS
# Amount of All Capitals words: 167840
#       Word  Frequency
# 0        A      46483
# 1        D      38021
# 2       TV       7814
# 3        E       4003
# 4        S       2411
# 5        B       2113
# 6      CGI       2095
# 7        O       2031
# 8        C       1801
# 9        J       1363
# 10     DVD       1323
# 11       T       1252
# 12      CI       1218
# 13       R       1146
# 14      OK       1144
# 15       F       1140
# 16      II       1120
# 17       L       1111
# 18       X        969
# 19       M        863
# 20     THE        774
# 21     FBI        702
# 22      US        692
# 23       K        682
# 24     BBC        676
# 25     HBO        616
# 26     CIA        585
# 27      PG        568
# 28       W        563
# 29       H        551
# 30       G        535
# 31      CA        518
# 32     NOT        512
# 33       P        505
# 34      UK        443
# 35       V        410
# 36    HAVE        381
# 37      FX        360
# 38      OF        318
# 39       N        313
# 40     III        309
# 41      NO        276
# 42      IS        267
# 43    WWII        252
# 44     AND        251
# 45       Z        234
# 46     USA        229
# 47    THAT        226
# 48  REVIEW        222
# 49     JFK        221
# lowercasing done
# stopword removal done
# Token Count:  10182482
# pos tagging done
# ######## Text Canonicalization
# port stemming done
# PREPROCESSING SUMMARY
# The number of numerics: 283397
# Numerics as percentage: 1.43%
# The number of punctuation and non-ascii: 3810439
# Punctuation and non-ascii as percentage: 19.17%
# The number of stop words: 6846701
# Stop words as percentage: 34.45%
# ######## DATA COMPLETION AFTER PREPROCESSING
# Empty preprocessed text: 0
# Duplicate preprocessed text: 0.00%
# After removing empty preprocessed texts:  75413
# ######## DEDUPLICATION AFTER PREPROCESSING
# Duplicate preprocessed text: 2981
# Duplicate preprocessed text: 3.95%
# After removing duplicate preprocessed texts:  72432
# ######### LAST CHECK
#                                           NODE  \
# 106197   _:node7788d74dd3601fb097d98e3c7d47d5a
# 106199   _:node4d3b78dd51f3c8821591f0407881d6e
# 106213  _:node62cf91e7dff8db325e6ad17b2ae1d072
# 106217    _:nodea1012d9b6581d91541b91e69ace29e
# 106219   _:nodeb95395167553f86eeeb94bb4f3eb0e3
#
#                                                 URL  \
# 106197  https://thereviewmonk.com/movie/chittagong/
# 106199  https://thereviewmonk.com/movie/chittagong/
# 106213  https://thereviewmonk.com/movie/chittagong/
# 106217  https://thereviewmonk.com/movie/chittagong/
# 106219  https://thereviewmonk.com/movie/chittagong/
#
#                                                      text REVIEWRATING  \
# 106197  " Shot ever so beautifully, Chittagong is a te...    "6"@en-US
# 106199  " This is a film that needs watching, because ...    "7"@en-US
# 106213  " Bedabrata Pain's Chittagong is a fitting tri...    "8"@en-US
# 106217  " Chittagong doesn\u2019t portray the Britishe...    "8"@en-US
# 106219  " In totality, \u2018Chittagong\u2019 is a mus...   "10"@en-US
#
#         BESTRATING WORSTRATING  mis_rat LANGUAGE  REVIEWRATING_new  \
# 106197  "10"@en-US   "0"@en-US     True       en               6.0
# 106199  "10"@en-US   "0"@en-US     True       en               7.0
# 106213  "10"@en-US   "0"@en-US     True       en               8.0
# 106217  "10"@en-US   "0"@en-US     True       en               8.0
# 106219  "10"@en-US   "0"@en-US     True       en              10.0
#
#         BESTRATING_new  WORSTRATING_new  label  \
# 106197            10.0              0.0      3
# 106199            10.0              0.0      4
# 106213            10.0              0.0      4
# 106217            10.0              0.0      4
# 106219            10.0              0.0      5
#
#                                                 text_prep  token_count  \
# 106197  shot ever beauti chittagong textur film but ma...           36
# 106199              film need watch u forget would tragic            7
# 106213  bedabrata pain chittagong fit tribut one impor...           31
# 106217  chittagong u portray british ogr sadist thank ...           44
# 106219       total u chittagong u must watch love countri            8
#
#         numerics_mix  punct_non_ascii   upper  stopwords  \
# 106197             3               16  [NASA]         20
# 106199             1                9      []         10
# 106213             1               10      []         20
# 106217             2               18      []         25
# 106219             1                8      []          7
#
#                                                       pos
# 106197  [(shot, NN), (ever, RB), (beautifully, RB), (c...
# 106199  [(film, NN), (needs, NNS), (watching, VBG), (u...
# 106213  [(bedabrata, NN), (pain, NN), (chittagong, JJ)...
# 106217  [(chittagong, JJ), (u, JJ), (portray, NN), (br...
# 106219  [(totality, NN), (u, NN), (chittagong, JJ), (u...
#                                           NODE  \
# count                                    72432
# unique                                   72432
# top     _:znodeqQpT7sEvTYpVwMugxcMZbCTEakjHAfT
# freq                                         1
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#                                                       URL  \
# count                                               72432
# unique                                              25064
# top     https://www.imdb.com/search/title/?title_type=...
# freq                                                  953
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      text REVIEWRATING  \
# count                                               72432        72432
# unique                                              72432          120
# top     "\nCanadian horror filmmaker Vincenzo Natali (...            3
# freq                                                    1         6086
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        BESTRATING WORSTRATING mis_rat LANGUAGE  REVIEWRATING_new  \
# count       72432       72432   72432    72432      72432.000000
# unique         12           8       1        1               NaN
# top            10           1    True       en               NaN
# freq        31280       36547   72432    72432               NaN
# mean          NaN         NaN     NaN      NaN         13.856345
# std           NaN         NaN     NaN      NaN         19.460281
# min           NaN         NaN     NaN      NaN          0.000000
# 25%           NaN         NaN     NaN      NaN          3.000000
# 50%           NaN         NaN     NaN      NaN          5.000000
# 75%           NaN         NaN     NaN      NaN         10.000000
# max           NaN         NaN     NaN      NaN         99.000000
#
#         BESTRATING_new  WORSTRATING_new         label  \
# count     72432.000000     72432.000000  72432.000000
# unique             NaN              NaN           NaN
# top                NaN              NaN           NaN
# freq               NaN              NaN           NaN
# mean         28.111429         0.507455      3.153206
# std          38.130622         0.498503      1.276403
# min           4.000000         0.000000      1.000000
# 25%           5.000000         0.000000      2.000000
# 50%          10.000000         1.000000      3.000000
# 75%          10.000000         1.000000      4.000000
# max          99.000000         1.000000      5.000000
#
#                                                 text_prep   token_count  \
# count                                               72432  72432.000000
# unique                                              72432           NaN
# top     wishi washi plot ideal televis serial make cri...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    139.685001
# std                                                   NaN    236.215997
# min                                                   NaN      1.000000
# 25%                                                   NaN     14.000000
# 50%                                                   NaN     33.000000
# 75%                                                   NaN    140.000000
# max                                                   NaN   4979.000000
#
#         numerics_mix  punct_non_ascii  upper     stopwords  \
# count   72432.000000     72432.000000  72432  72432.000000
# unique           NaN              NaN  16078           NaN
# top              NaN              NaN     []           NaN
# freq             NaN              NaN  41034           NaN
# mean        3.905097        52.198572    NaN     93.892106
# std        13.906587        91.311897    NaN    148.684884
# min         0.000000         0.000000    NaN      0.000000
# 25%         0.000000         4.000000    NaN      9.000000
# 50%         0.000000        11.000000    NaN     24.000000
# 75%         2.000000        42.000000    NaN    110.000000
# max       350.000000      1405.000000    NaN   2873.000000
#
#                                                       pos
# count                                               72432
# unique                                              72432
# top     [(tv, NN), (movies, NNS), (aimed, VBN), (midda...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# ######## DATA SOURCES
# Total netloc distribution
# www.imdb.com               27155
# reviewschview.com          16203
# www.rogerebert.com          9713
# www.empireonline.com        8457
# thereviewmonk.com           5530
# deepfocusreview.com         2090
# www.telegraph.co.uk         1151
# www.rollingstone.com         956
# www.flickfilosopher.com      951
# www.noopler.com              202
# nationalpost.com              24
# Name: netloc, dtype: int64
# extracted netloc distribution
# www.rogerebert.com         9713
# reviewschview.com          3275
# thereviewmonk.com          1405
# deepfocusreview.com        1132
# www.flickfilosopher.com     766
# www.telegraph.co.uk         216
# www.noopler.com             202
# nationalpost.com             24
# Name: netloc, dtype: int64
# scraped netloc distribution
# www.imdb.com               27155
# reviewschview.com          12928
# www.empireonline.com        8457
# thereviewmonk.com           4125
# deepfocusreview.com          958
# www.rollingstone.com         956
# www.telegraph.co.uk          935
# www.flickfilosopher.com      185
# Name: netloc, dtype: int64
# #### All sources across ratings
# #### rating class 1.0
# www.imdb.com               5423
# reviewschview.com          2352
# thereviewmonk.com           495
# www.empireonline.com        374
# www.rogerebert.com          194
# www.flickfilosopher.com     169
# www.telegraph.co.uk          79
# deepfocusreview.com          59
# www.rollingstone.com         21
# www.noopler.com               9
# Name: netloc, dtype: int64
# #### rating class 2.0
# reviewschview.com          5464
# www.imdb.com               3654
# www.empireonline.com       1727
# thereviewmonk.com          1405
# www.rogerebert.com         1228
# deepfocusreview.com         307
# www.telegraph.co.uk         244
# www.flickfilosopher.com     130
# www.rollingstone.com        109
# www.noopler.com              16
# nationalpost.com              5
# Name: netloc, dtype: int64
# #### rating class 3.0
# reviewschview.com          5609
# www.imdb.com               4726
# www.empireonline.com       3101
# thereviewmonk.com          1878
# www.rogerebert.com         1477
# www.telegraph.co.uk         335
# deepfocusreview.com         259
# www.flickfilosopher.com     163
# www.rollingstone.com        140
# www.noopler.com              29
# nationalpost.com              5
# Name: netloc, dtype: int64
# #### rating class 4.0
# www.imdb.com               6057
# www.rogerebert.com         4029
# www.empireonline.com       2701
# reviewschview.com          2597
# thereviewmonk.com          1537
# deepfocusreview.com         676
# www.rollingstone.com        425
# www.telegraph.co.uk         353
# www.flickfilosopher.com     294
# www.noopler.com              78
# nationalpost.com              9
# Name: netloc, dtype: int64
# #### rating class 5.0
# www.imdb.com               7295
# www.rogerebert.com         2785
# deepfocusreview.com         789
# www.empireonline.com        554
# www.rollingstone.com        261
# thereviewmonk.com           215
# www.flickfilosopher.com     195
# reviewschview.com           181
# www.telegraph.co.uk         140
# www.noopler.com              70
# nationalpost.com              5
# Name: netloc, dtype: int64
# ######## STORING
# to pickle done
# C:\Users\D064966\PycharmProjects\Master\Scripts\profiling.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mis_rat'] = df.apply(checkmisrat, axis=1)
