# %%
# Imports
import logging, sqlite3, re, gzip, pandas as pd

# %%
# Input:
movies_path = '../Data/schema_Movie.gz'
reviews_path= '../Data/schema_Review.gz'
inputlist = [movies_path,reviews_path]

# Output:
moviereviewslog_path = '../Logs/movieReviews.log'
moviereviewsdb_path = '../Data/moviereviews.db'

# enable Logging:
logger = logging.getLogger()
fhandler = logging.FileHandler(filename=moviereviewslog_path, mode='a')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.DEBUG)

# %%
conn = sqlite3.connect(moviereviewsdb_path)
c = conn.cursor()
c.execute("""
        CREATE TABLE IF NOT EXISTS
            moviereviews(
                NODE TEXT,
                URL TEXT,
                REVIEWBODY TEXT,
                RATING TEXT,
                REVIEWRATING TEXT,
                BESTRATING TEXT,
                WORSTRATING TEXT,
                PRIMARY KEY (NODE, URL))
    """)

# %%
# Pattern
taxo_pattern = re.compile("<http://schema.org/Review/description>|"\
                          "<http://schema.org/Review/reviewBody>|"\
                          "<http://schema.org/Review/reviewRating>|"\
                          "<http://schema.org/Rating/worstRating>|"\
                          "<http://schema.org/Rating/bestRating>|"\
                          "<http://schema.org/Rating/ratingValue>", re.IGNORECASE)
split_pattern = re.compile("^(_:.*)\s<(.*)>\s(.*)\s<(.*)>\s\.$", re.IGNORECASE)

# Search based on url of valid movie and tv reviews
url_lst = ['https://in.bookmyshow.com', 'https://thereviewmonk.com',
           'https://www.noopler.com', 'http://reviewschview.com',
           'https://www.flickfilosopher.com', 'https://www.rogerebert.com',
           'https://deepfocusreview.com', 'https://www.telegraph.co.uk',
           'https://nationalpost.com', 'https://www.imdb.com']
for input in inputlist:
    for url in url_lst:
        url_pattern = re.compile(url,re.IGNORECASE)
        with gzip.open(input,"rt") as f:
            i = 0
            detected = 0
            skipped = 0
            not_taxo = 0
            not_url = 0
            inserted = 0
            failed_updates = 0
            for line in f:
                i += 1
                if not url_pattern.search(line):
                    not_url += 1
                    continue
                if not taxo_pattern.search(line):
                    not_taxo
                    continue
                match = split_pattern.match(line)
                if match is None:
                    skipped += 1
                    continue
                detected += 1
                props = match.groups()
                subj = props[0]
                predicate = props[1]
                obj = props[2]
                source = props[3]
                c.execute("INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?);",(subj, source))
                update_query = "UPDATE moviereviews SET "
                params = [obj, subj, source]
                if predicate.lower() == "http://schema.org/Review/reviewBody".lower():
                    update_query += "REVIEWBODY = ? "
                if predicate.lower() == "http://schema.org/Review/description".lower():
                    update_query += "REVIEWBODY = ? "
                if predicate.lower() == "http://schema.org/Review/reviewRating".lower():
                    update_query += "RATING = ? "
                if predicate.lower() == "http://schema.org/Rating/ratingValue".lower():
                    update_query += "REVIEWRATING = ? "
                if predicate.lower() == "http://schema.org/Rating/bestRating".lower():
                    update_query += "BESTRATING = ? "
                if predicate.lower() == "http://schema.org/Rating/worstRating".lower():
                    update_query += "WORSTRATING = ? "
                update_query += "WHERE NODE = ? AND URL = ?;"
                try:
                    conn.execute(update_query, params)
                    conn.commit()
                    inserted += 1
                except:
                    logging.debug("failed to execute for params " + str(update_query) + str(props))
                    failed_updates += 1

logging.debug("detected " + str(detected) + ", inserted: " + str(inserted) +" lines out of " + str(i) + "; not in taxo: " + str(not_taxo))
logging.debug("Done processing the movie reviews file from Movie.gz and Review.gz after the database got deleted")
# Out:
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea456ab92b2669279485e1ddc64944bf0', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is about the mistaken identities, goofy plans, and some silly, and sometimes hilarious punches."@en', '_:nodea456ab92b2669279485e1ddc64944bf0', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee7b066aef1465ef6796152d5b23eefd', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodee7b066aef1465ef6796152d5b23eefd', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee7b066aef1465ef6796152d5b23eefd', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodee7b066aef1465ef6796152d5b23eefd', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee7b066aef1465ef6796152d5b23eefd', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodee7b066aef1465ef6796152d5b23eefd', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea456ab92b2669279485e1ddc64944bf0', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodee7b066aef1465ef6796152d5b23eefd', '_:nodea456ab92b2669279485e1ddc64944bf0', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node3b52118bf545246233aa662aad8a194', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Overall, Housefull 4 ends up as a complete mad caper. Which, if you`re a fan of the Housefull brand of comedy, might appeal to you."@en', '_:node3b52118bf545246233aa662aad8a194', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef82d8af1d090997015dbe94ab45ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodef82d8af1d090997015dbe94ab45ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef82d8af1d090997015dbe94ab45ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodef82d8af1d090997015dbe94ab45ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef82d8af1d090997015dbe94ab45ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodef82d8af1d090997015dbe94ab45ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node3b52118bf545246233aa662aad8a194', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodef82d8af1d090997015dbe94ab45ad', '_:node3b52118bf545246233aa662aad8a194', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeecc0f025103514ba011df1542adef7b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"HOUSEFULL 4 is a major disappointment and suffers on the account of poor writing and vacuous screenplay."@en', '_:nodeecc0f025103514ba011df1542adef7b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node5e5e1ef8427cb3f95ead0badefcd4c8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node5e5e1ef8427cb3f95ead0badefcd4c8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node5e5e1ef8427cb3f95ead0badefcd4c8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node5e5e1ef8427cb3f95ead0badefcd4c8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node5e5e1ef8427cb3f95ead0badefcd4c8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node5e5e1ef8427cb3f95ead0badefcd4c8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeecc0f025103514ba011df1542adef7b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node5e5e1ef8427cb3f95ead0badefcd4c8', '_:nodeecc0f025103514ba011df1542adef7b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6b881073d43973e4559d40a729a1a3a3', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a mildly funny reincarnation comedy with a lot of forgettable slapstick humour."@en', '_:node6b881073d43973e4559d40a729a1a3a3', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node78d3562567ab738b3d2d697baa1abe', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node78d3562567ab738b3d2d697baa1abe', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node78d3562567ab738b3d2d697baa1abe', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node78d3562567ab738b3d2d697baa1abe', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node78d3562567ab738b3d2d697baa1abe', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node78d3562567ab738b3d2d697baa1abe', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6b881073d43973e4559d40a729a1a3a3', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node78d3562567ab738b3d2d697baa1abe', '_:node6b881073d43973e4559d40a729a1a3a3', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node443f597df6a943dcd6f531f61603e9b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The film is a reincarnation comedy. If you have followed the franchise and have seen the trailer of Housefull 4, you know what you are in for"@en', '_:node443f597df6a943dcd6f531f61603e9b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6c2431474bd1e4e46bcfccc88565eb24', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node6c2431474bd1e4e46bcfccc88565eb24', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6c2431474bd1e4e46bcfccc88565eb24', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node6c2431474bd1e4e46bcfccc88565eb24', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6c2431474bd1e4e46bcfccc88565eb24', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node6c2431474bd1e4e46bcfccc88565eb24', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node443f597df6a943dcd6f531f61603e9b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node6c2431474bd1e4e46bcfccc88565eb24', '_:node443f597df6a943dcd6f531f61603e9b', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef4d825171236c87d35b239a9f90482a', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"This reincarnation comedy has a lot of crass humour and some of it is even homophobic"@en', '_:nodef4d825171236c87d35b239a9f90482a', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node67892128477dc9ae56f4f5cd912b8266', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node67892128477dc9ae56f4f5cd912b8266', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node67892128477dc9ae56f4f5cd912b8266', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node67892128477dc9ae56f4f5cd912b8266', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node67892128477dc9ae56f4f5cd912b8266', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node67892128477dc9ae56f4f5cd912b8266', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef4d825171236c87d35b239a9f90482a', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node67892128477dc9ae56f4f5cd912b8266', '_:nodef4d825171236c87d35b239a9f90482a', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node1ecd67e87076a52794c045c193f0df', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a good watch for Diwali when you certainly want something funny happening around you  and not the characteristic day-to-day stress of the other 360 days of the year."@en', '_:node1ecd67e87076a52794c045c193f0df', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:noded3c885aa4f711824d595f131fc1da91', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:noded3c885aa4f711824d595f131fc1da91', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:noded3c885aa4f711824d595f131fc1da91', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:noded3c885aa4f711824d595f131fc1da91', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:noded3c885aa4f711824d595f131fc1da91', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:noded3c885aa4f711824d595f131fc1da91', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node1ecd67e87076a52794c045c193f0df', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:noded3c885aa4f711824d595f131fc1da91', '_:node1ecd67e87076a52794c045c193f0df', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node74ee5e858d418449953be3ca2cbd6828', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is about the mistaken identities, goofy plans, and some silly, and sometimes hilarious punches."@en', '_:node74ee5e858d418449953be3ca2cbd6828', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node2b2489837c4d828e9eac759cfebdbfa8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Overall, Housefull 4 ends up as a complete mad caper. Which, if you`re a fan of the Housefull brand of comedy, might appeal to you."@en', '_:node2b2489837c4d828e9eac759cfebdbfa8', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node27fb183db8791068a3f1b1162add7a15', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"HOUSEFULL 4 is a major disappointment and suffers on the account of poor writing and vacuous screenplay."@en', '_:node27fb183db8791068a3f1b1162add7a15', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodefdb271eed112635ed4c670364794a4f0', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a mildly funny reincarnation comedy with a lot of forgettable slapstick humour."@en', '_:nodefdb271eed112635ed4c670364794a4f0', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node25f8b0ca99abcc784ae5f8bdc42f42', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The film is a reincarnation comedy. If you have followed the franchise and have seen the trailer of Housefull 4, you know what you are in for"@en', '_:node25f8b0ca99abcc784ae5f8bdc42f42', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea1fdf8f8807e5dcc3547046601718cb', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"This reincarnation comedy has a lot of crass humour and some of it is even homophobic"@en', '_:nodea1fdf8f8807e5dcc3547046601718cb', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef2351083309eef29e369949a64ec6ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a good watch for Diwali when you certainly want something funny happening around you  and not the characteristic day-to-day stress of the other 360 days of the year."@en', '_:nodef2351083309eef29e369949a64ec6ad', 'https://in.bookmyshow.com/amritsar/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee5162980a8b5f68bef01150a01548ed', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Except for the two relatively unpredictable climax scenes, both delivered unconvincingly, there is not much to hold onto. The basic problem of the film is that the characters lack depth, and for the story of this nature, the dialogues barely add weight. You wont miss Shakti Kapoors rather displaced public service announcement towards the end, where he not only condemns the triple talaq practice, but adds another hiccup in the already faulty narrative."@en', '_:nodee5162980a8b5f68bef01150a01548ed', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeb7aba67dc20dc53c739c5c6691679f9', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodeb7aba67dc20dc53c739c5c6691679f9', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeb7aba67dc20dc53c739c5c6691679f9', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodeb7aba67dc20dc53c739c5c6691679f9', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeb7aba67dc20dc53c739c5c6691679f9', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodeb7aba67dc20dc53c739c5c6691679f9', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee5162980a8b5f68bef01150a01548ed', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodeb7aba67dc20dc53c739c5c6691679f9', '_:nodee5162980a8b5f68bef01150a01548ed', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node2834d53d99f267ce56cab27727dc75cb', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Except for the two relatively unpredictable climax scenes, both delivered unconvincingly, there is not much to hold onto. The basic problem of the film is that the characters lack depth, and for the story of this nature, the dialogues barely add weight. You wont miss Shakti Kapoors rather displaced public service announcement towards the end, where he not only condemns the triple talaq practice, but adds another hiccup in the already faulty narrative."@en', '_:node2834d53d99f267ce56cab27727dc75cb', 'https://in.bookmyshow.com/bahadurgarh/movies/yaaram/ET00112049']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node129324fe6f6ef2f34294bd997d1b59', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"`Pehlwaan` brings in all the needed masala elements via comedy, romance, fights and abundance of emotions."@en', '_:node129324fe6f6ef2f34294bd997d1b59', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef2f620dec5442e9aac43f99ce133ad', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"3.5"@en', '_:nodef2f620dec5442e9aac43f99ce133ad', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef2f620dec5442e9aac43f99ce133ad', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodef2f620dec5442e9aac43f99ce133ad', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef2f620dec5442e9aac43f99ce133ad', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodef2f620dec5442e9aac43f99ce133ad', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node129324fe6f6ef2f34294bd997d1b59', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodef2f620dec5442e9aac43f99ce133ad', '_:node129324fe6f6ef2f34294bd997d1b59', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodec4611236f99c9c26ba1bd568c08b2bc1', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Kichcha Sudeepa shines without an iota of doubt, starting with his hard work to transform his body into a professional wrestler."@en', '_:nodec4611236f99c9c26ba1bd568c08b2bc1', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodedae8e2b6f6f9b89cfbea433538fbc050', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"3.5"@en', '_:nodedae8e2b6f6f9b89cfbea433538fbc050', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodedae8e2b6f6f9b89cfbea433538fbc050', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodedae8e2b6f6f9b89cfbea433538fbc050', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodedae8e2b6f6f9b89cfbea433538fbc050', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodedae8e2b6f6f9b89cfbea433538fbc050', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodec4611236f99c9c26ba1bd568c08b2bc1', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodedae8e2b6f6f9b89cfbea433538fbc050', '_:nodec4611236f99c9c26ba1bd568c08b2bc1', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node95ee87aae03694ea128bc3e6ac951055', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Kichcha Sudeepa and Suniel Shetty`s film entertains despite a lengthy climax."@en', '_:node95ee87aae03694ea128bc3e6ac951055', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node16fb219a7bac5bef73a33a2a8addb44', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"3.5"@en', '_:node16fb219a7bac5bef73a33a2a8addb44', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node16fb219a7bac5bef73a33a2a8addb44', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node16fb219a7bac5bef73a33a2a8addb44', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node16fb219a7bac5bef73a33a2a8addb44', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node16fb219a7bac5bef73a33a2a8addb44', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node95ee87aae03694ea128bc3e6ac951055', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node16fb219a7bac5bef73a33a2a8addb44', '_:node95ee87aae03694ea128bc3e6ac951055', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node70156a9c336e6b202011f2b27e7d72', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Verdict: Pailwaan is moving and will undoubtedly give you goosebumps. Following the footsteps of Baahubali, subsequent southern movies that have rich content and universal appeal have been making their presence felt. Films like KGF and Saaho are classic examples from the recent past. Pailwaan, starring Kiccha Sudeep, is testing its luck today by releasing in five different languages across the cou..."@en', '_:node70156a9c336e6b202011f2b27e7d72', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node59bb17ceaceeb1e726b8aa1f3e2679', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"`Pehlwaan` brings in all the needed masala elements via comedy, romance, fights and abundance of emotions."@en', '_:node59bb17ceaceeb1e726b8aa1f3e2679', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node179df380afbcad3cc27c6885aa699abc', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Kichcha Sudeepa shines without an iota of doubt, starting with his hard work to transform his body into a professional wrestler."@en', '_:node179df380afbcad3cc27c6885aa699abc', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebe44befc5cacd74eba634ef8b21ddebe', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Kichcha Sudeepa and Suniel Shetty`s film entertains despite a lengthy climax."@en', '_:nodebe44befc5cacd74eba634ef8b21ddebe', 'https://in.bookmyshow.com/bengaluru/movies/pailwaan/ET00061622/user-reviews']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node87db63e16c464bc508aabab38bad580', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is about the mistaken identities, goofy plans, and some silly, and sometimes hilarious punches."@en', '_:node87db63e16c464bc508aabab38bad580', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebdd786bd1b9dcf6decf262566873427e', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodebdd786bd1b9dcf6decf262566873427e', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebdd786bd1b9dcf6decf262566873427e', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodebdd786bd1b9dcf6decf262566873427e', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebdd786bd1b9dcf6decf262566873427e', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodebdd786bd1b9dcf6decf262566873427e', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node87db63e16c464bc508aabab38bad580', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodebdd786bd1b9dcf6decf262566873427e', '_:node87db63e16c464bc508aabab38bad580', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebb35e1693fc3423bdca1e62c8fe9d88', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Overall, Housefull 4 ends up as a complete mad caper. Which, if you`re a fan of the Housefull brand of comedy, might appeal to you."@en', '_:nodebb35e1693fc3423bdca1e62c8fe9d88', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee019e3bbd2f8421cc2dc1cb86dbb065', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodee019e3bbd2f8421cc2dc1cb86dbb065', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee019e3bbd2f8421cc2dc1cb86dbb065', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodee019e3bbd2f8421cc2dc1cb86dbb065', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee019e3bbd2f8421cc2dc1cb86dbb065', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodee019e3bbd2f8421cc2dc1cb86dbb065', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebb35e1693fc3423bdca1e62c8fe9d88', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodee019e3bbd2f8421cc2dc1cb86dbb065', '_:nodebb35e1693fc3423bdca1e62c8fe9d88', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node1c9179abcebdc19a1a13f3b8a357aa90', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"HOUSEFULL 4 is a major disappointment and suffers on the account of poor writing and vacuous screenplay."@en', '_:node1c9179abcebdc19a1a13f3b8a357aa90', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node1c9179abcebdc19a1a13f3b8a357aa90', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodea2cc279b1f86a2b0e8cc2d378d5d0ca', '_:node1c9179abcebdc19a1a13f3b8a357aa90', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef7a302f22dc2610807bee2cee4b0d4', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a mildly funny reincarnation comedy with a lot of forgettable slapstick humour."@en', '_:nodef7a302f22dc2610807bee2cee4b0d4', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node7d32c61aae58d77497e5104ec56b3c', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node7d32c61aae58d77497e5104ec56b3c', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node7d32c61aae58d77497e5104ec56b3c', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node7d32c61aae58d77497e5104ec56b3c', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node7d32c61aae58d77497e5104ec56b3c', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node7d32c61aae58d77497e5104ec56b3c', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodef7a302f22dc2610807bee2cee4b0d4', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node7d32c61aae58d77497e5104ec56b3c', '_:nodef7a302f22dc2610807bee2cee4b0d4', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node3376a976226fc28567d6e61fc9dc290', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The film is a reincarnation comedy. If you have followed the franchise and have seen the trailer of Housefull 4, you know what you are in for"@en', '_:node3376a976226fc28567d6e61fc9dc290', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6791945b74ba133077ebe54d454fde6', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node6791945b74ba133077ebe54d454fde6', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6791945b74ba133077ebe54d454fde6', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node6791945b74ba133077ebe54d454fde6', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6791945b74ba133077ebe54d454fde6', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node6791945b74ba133077ebe54d454fde6', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node3376a976226fc28567d6e61fc9dc290', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node6791945b74ba133077ebe54d454fde6', '_:node3376a976226fc28567d6e61fc9dc290', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodecea3b17b718da7d77c530f917e52b0', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"This reincarnation comedy has a lot of crass humour and some of it is even homophobic"@en', '_:nodecea3b17b718da7d77c530f917e52b0', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea475787ffbe889e8c0d1476e021ac', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodea475787ffbe889e8c0d1476e021ac', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea475787ffbe889e8c0d1476e021ac', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodea475787ffbe889e8c0d1476e021ac', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea475787ffbe889e8c0d1476e021ac', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodea475787ffbe889e8c0d1476e021ac', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodecea3b17b718da7d77c530f917e52b0', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodea475787ffbe889e8c0d1476e021ac', '_:nodecea3b17b718da7d77c530f917e52b0', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodece6327bdd2cecaac2e715b999635e25b', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a good watch for Diwali when you certainly want something funny happening around you  and not the characteristic day-to-day stress of the other 360 days of the year."@en', '_:nodece6327bdd2cecaac2e715b999635e25b', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebddac86a0ad1fdf5e5bcfdf631c87', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:nodebddac86a0ad1fdf5e5bcfdf631c87', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebddac86a0ad1fdf5e5bcfdf631c87', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodebddac86a0ad1fdf5e5bcfdf631c87', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebddac86a0ad1fdf5e5bcfdf631c87', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:nodebddac86a0ad1fdf5e5bcfdf631c87', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodece6327bdd2cecaac2e715b999635e25b', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:nodebddac86a0ad1fdf5e5bcfdf631c87', '_:nodece6327bdd2cecaac2e715b999635e25b', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodec13a23d0a857ecaec56340f7569eedf', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is about the mistaken identities, goofy plans, and some silly, and sometimes hilarious punches."@en', '_:nodec13a23d0a857ecaec56340f7569eedf', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:noded08534653d72d893657ed689277ca328', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Overall, Housefull 4 ends up as a complete mad caper. Which, if you`re a fan of the Housefull brand of comedy, might appeal to you."@en', '_:noded08534653d72d893657ed689277ca328', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node46c896838f8469ed9976b528e755d754', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"HOUSEFULL 4 is a major disappointment and suffers on the account of poor writing and vacuous screenplay."@en', '_:node46c896838f8469ed9976b528e755d754', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node654b4c32be91bce634d2da9796b17429', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a mildly funny reincarnation comedy with a lot of forgettable slapstick humour."@en', '_:node654b4c32be91bce634d2da9796b17429', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6add38ebcc52adc4517753cf2ae561', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The film is a reincarnation comedy. If you have followed the franchise and have seen the trailer of Housefull 4, you know what you are in for"@en', '_:node6add38ebcc52adc4517753cf2ae561', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeec5e976b7e3b4ae57a4c7e415efe219f', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"This reincarnation comedy has a lot of crass humour and some of it is even homophobic"@en', '_:nodeec5e976b7e3b4ae57a4c7e415efe219f', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9477785dfddb88b850b47d23953eb5', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Housefull 4 is a good watch for Diwali when you certainly want something funny happening around you  and not the characteristic day-to-day stress of the other 360 days of the year."@en', '_:node9477785dfddb88b850b47d23953eb5', 'https://in.bookmyshow.com/movies/housefull-4/ET00064161']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodec0224fe2cd4e4564d99fda2130cb9b', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The film is congenial and establishes the feel-good factor from frame one and maintains it till the curtains are drawn."@en', '_:nodec0224fe2cd4e4564d99fda2130cb9b', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node889a67f01c3b2fe6ebb08951bfbf36f', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node889a67f01c3b2fe6ebb08951bfbf36f', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node889a67f01c3b2fe6ebb08951bfbf36f', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node889a67f01c3b2fe6ebb08951bfbf36f', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node889a67f01c3b2fe6ebb08951bfbf36f', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node889a67f01c3b2fe6ebb08951bfbf36f', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodec0224fe2cd4e4564d99fda2130cb9b', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node889a67f01c3b2fe6ebb08951bfbf36f', '_:nodec0224fe2cd4e4564d99fda2130cb9b', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node56903564ba5c219969c01ca666c413', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"If you are in for a light hearted comedy and have no clue of the story beats of the original film, you and your kids might actually enjoy the film."@en', '_:node56903564ba5c219969c01ca666c413', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node649898c7a85ce4cf21255d3c144a', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node649898c7a85ce4cf21255d3c144a', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node649898c7a85ce4cf21255d3c144a', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node649898c7a85ce4cf21255d3c144a', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node649898c7a85ce4cf21255d3c144a', 'https://in.bookmyshow.com/muzaffarpur/movies/aladdin/ET00086118')
# ...
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node3262706b8c41d9388d5686a8754c5c56', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node3262706b8c41d9388d5686a8754c5c56', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodea81357e2d2141799e19427bf4a970f4', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node3262706b8c41d9388d5686a8754c5c56', '_:nodea81357e2d2141799e19427bf4a970f4', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node2211122a992fb7f919234789c0884a', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The last time Hrithik looked as sexy, was in Dhoom 2 ( 2006), also a Yash Raj film. The golden streaks have been replaced with a bit of grey at the temples, but the bronzed cheekbones decorated with a few fetching scars, is full eye-candy. I am not revealing anything by telling you that War looks all set to be a franchise: next time maybe go full comic-book? Now thats a spy I will buy."@en', '_:node2211122a992fb7f919234789c0884a', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node8e5062e279f2bf17b6be3995e7640fd', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node8e5062e279f2bf17b6be3995e7640fd', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node8e5062e279f2bf17b6be3995e7640fd', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node8e5062e279f2bf17b6be3995e7640fd', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node8e5062e279f2bf17b6be3995e7640fd', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node8e5062e279f2bf17b6be3995e7640fd', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node2211122a992fb7f919234789c0884a', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node8e5062e279f2bf17b6be3995e7640fd', '_:node2211122a992fb7f919234789c0884a', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6d69fed68232b681aadab626f6d4c3', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"War is undoubtedly an entertaining Bollywood thriller with two superstars of two different generations giving ample opportunities to start a social media war on who was better. After a long time, we have a film which is better than its trailer. WAR is a combination of well-blended masala, powerful action scenes, unpredictable twists and a required dose of patriotism. Something, you can watch and enjoy."@en', '_:node6d69fed68232b681aadab626f6d4c3', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6d69fed68232b681aadab626f6d4c3', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node9992f55e5d8bf7df9d9e4f6a1ca46aad', '_:node6d69fed68232b681aadab626f6d4c3', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee58f09daf29b27ed4297f0cc4eef1b', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"War is a decent addition to both actors` action film legacy. But this high-profile bang bang show is at best, popcorn entertainment for action movie buffs."@en', '_:nodee58f09daf29b27ed4297f0cc4eef1b', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9b939ff94173cf3dbd54037cad7364f', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node9b939ff94173cf3dbd54037cad7364f', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9b939ff94173cf3dbd54037cad7364f', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node9b939ff94173cf3dbd54037cad7364f', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9b939ff94173cf3dbd54037cad7364f', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node9b939ff94173cf3dbd54037cad7364f', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodee58f09daf29b27ed4297f0cc4eef1b', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node9b939ff94173cf3dbd54037cad7364f', '_:nodee58f09daf29b27ed4297f0cc4eef1b', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9334282d260a0d347315c2650c782e2', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Hrithik Roshan is the film`s greatest asset. He is gorgeous, the salt and pepper look suits his gracefully aging face beautifully, and despite occasional over-wrought emotional histrionics he does a decent acting job. But the nasal, throaty  dialogue delivery that has been his signature so far is so overdone here that it is sometimes hard to decipher the lines he speaks."@en', '_:node9334282d260a0d347315c2650c782e2', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node35c242cb9772ca6960abc7ff4dd67b0', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node35c242cb9772ca6960abc7ff4dd67b0', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node35c242cb9772ca6960abc7ff4dd67b0', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node35c242cb9772ca6960abc7ff4dd67b0', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node35c242cb9772ca6960abc7ff4dd67b0', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node35c242cb9772ca6960abc7ff4dd67b0', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9334282d260a0d347315c2650c782e2', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node35c242cb9772ca6960abc7ff4dd67b0', '_:node9334282d260a0d347315c2650c782e2', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node72283cf756756e4d986cde7ea63598ce', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"If only the writers brought their A-game like the actors did."@en', '_:node72283cf756756e4d986cde7ea63598ce', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node807775292f4473ad68102874ed139272', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET WORSTRATING = ? WHERE NODE = ? AND URL = ?; ['"2"@en', '_:node807775292f4473ad68102874ed139272', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node807775292f4473ad68102874ed139272', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET BESTRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node807775292f4473ad68102874ed139272', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node807775292f4473ad68102874ed139272', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWRATING = ? WHERE NODE = ? AND URL = ?; ['"Null"@en', '_:node807775292f4473ad68102874ed139272', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node72283cf756756e4d986cde7ea63598ce', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET RATING = ? WHERE NODE = ? AND URL = ?; ['_:node807775292f4473ad68102874ed139272', '_:node72283cf756756e4d986cde7ea63598ce', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node19c0605c944dbe206071f61ab239ebe', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Verdict: Hrithik and Tiger make a powerful duo in this well-directed entertainer. The buzz for War has been constant ever since the action film starring both Hrithik Roshan and Tiger Shroff was announced. Under the Yash Raj Films banner, it features the two Bollywood icons pitted against each other in a ferocious face-off, promising high octane action in a high stakes plot. Sounds epic, right? Let..."@en', '_:node19c0605c944dbe206071f61ab239ebe', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodeb17ba23d621853a95a335e1b18dc8', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Hrithik Roshan and Tiger Shroff-starrer is a gripping action fest so far"@en', '_:nodeb17ba23d621853a95a335e1b18dc8', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodecf1e185b382f11515c02ab4837b8e2d', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"The last time Hrithik looked as sexy, was in Dhoom 2 ( 2006), also a Yash Raj film. The golden streaks have been replaced with a bit of grey at the temples, but the bronzed cheekbones decorated with a few fetching scars, is full eye-candy. I am not revealing anything by telling you that War looks all set to be a franchise: next time maybe go full comic-book? Now thats a spy I will buy."@en', '_:nodecf1e185b382f11515c02ab4837b8e2d', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node13ebdc7e9fbeaf692d8b9e83aaf4199b', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"War is undoubtedly an entertaining Bollywood thriller with two superstars of two different generations giving ample opportunities to start a social media war on who was better. After a long time, we have a film which is better than its trailer. WAR is a combination of well-blended masala, powerful action scenes, unpredictable twists and a required dose of patriotism. Something, you can watch and enjoy."@en', '_:node13ebdc7e9fbeaf692d8b9e83aaf4199b', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:nodebe8696c084e2b8a6a6d28619deafb39', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"War is a decent addition to both actors` action film legacy. But this high-profile bang bang show is at best, popcorn entertainment for action movie buffs."@en', '_:nodebe8696c084e2b8a6a6d28619deafb39', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node9e9238a7f1bd4bc8875c0afa99876a6', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"Hrithik Roshan is the film`s greatest asset. He is gorgeous, the salt and pepper look suits his gracefully aging face beautifully, and despite occasional over-wrought emotional histrionics he does a decent acting job. But the nasal, throaty  dialogue delivery that has been his signature so far is so overdone here that it is sometimes hard to decipher the lines he speaks."@en', '_:node9e9238a7f1bd4bc8875c0afa99876a6', 'https://in.bookmyshow.com/movies/war/ET00107162']
# INSERT OR IGNORE INTO MOVIEREVIEWS (NODE, URL) VALUES (?,?); ('_:node6e41a5b291a0fd9a9623c39e430f962', 'https://in.bookmyshow.com/movies/war/ET00107162')
# UPDATE MOVIEREVIEWS SET REVIEWBODY = ? WHERE NODE = ? AND URL = ?; ['"If only the writers brought their A-game like the actors did."@en', '_:node6e41a5b291a0fd9a9623c39e430f962', 'https://in.bookmyshow.com/movies/war/ET00107162']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a65b7d8e6941> in <module>
#      34             failed_updates = 0
#      35             # head = [next(f) for x in range(5000000)]
# ---> 36             for line in f:
#      37             # for line in head:
#      38                 i += 1
#
# c:\users\d064966\appdata\local\continuum\anaconda3\envs\masterthesis\lib\gzip.py in read1(self, size)
#     298         if size < 0:
#     299             size = io.DEFAULT_BUFFER_SIZE
# --> 300         return self._buffer.read1(size)
#     301
#     302     def peek(self, n):
#
# c:\users\d064966\appdata\local\continuum\anaconda3\envs\masterthesis\lib\_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# c:\users\d064966\appdata\local\continuum\anaconda3\envs\masterthesis\lib\gzip.py in read(self, size)
#     480             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     481
# --> 482             uncompress = self._decompressor.decompress(buf, size)
#     483             if self._decompressor.unconsumed_tail != b"":
#     484                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
merge_query = "UPDATE moviereviews "\
              "SET REVIEWRATING = (SELECT T.REVIEWRATING FROM moviereviews AS T "\
              "WHERE moviereviews.RATING = T.NODE AND moviereviews.URL = T.URL), "\
              "BESTRATING = (SELECT T.BESTRATING FROM moviereviews AS T "\
              "WHERE moviereviews.RATING = T.NODE AND moviereviews.URL = T.URL), "\
              "WORSTRATING = (SELECT T.WORSTRATING FROM moviereviews AS T "\
              "WHERE moviereviews.RATING = T.NODE AND moviereviews.URL = T.URL) "\
              "WHERE RATING IN (SELECT NODE FROM moviereviews);"

c.execute(merge_query)
conn.commit()
